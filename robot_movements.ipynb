# %%
import random
import time
import pandas as pd
from datetime import datetime

robot_names = ["RobotA", "RobotB", "RobotC"]
moves = ["grab", "set", "implement"]

def generate_robot_data(robot_name):
    robot_moves = [random.choice(moves) for _ in range(3)]
    times = [random.uniform(0.1, 2.0) for _ in range(3)]
    total_time = sum(times)
    return {"Robot Name": robot_name, "Moves": robot_moves, "Times": times, "Total Time": total_time}

def main():
    data_list = []

    iteration_count = 0

    while True:
        for robot_name in robot_names:
            robot_data = generate_robot_data(robot_name)
            for move, time_taken in zip(robot_data["Moves"], robot_data["Times"]):
                timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                data_list.append([robot_name, move, timestamp, time_taken])

                # Display each line of output
                print(f"{timestamp} - {robot_name} - Move: {move}, Time: {time_taken:.2f} seconds")
                time.sleep(1)

                # Check with the user after every 10 lines
                if len(data_list) % 100 == 0:
                    stop = input("Do you want to stop? (yes/no): ")
                    if stop.lower() == "yes":
                        # Creating a DataFrame from the collected data
                        columns = ["Robot Name", "Move", "Timestamp", "Time"]
                        df = pd.DataFrame(data_list, columns=columns)

                        # Export DataFrame to JSON file
                        json_filename = f"robot_movement_data_{iteration_count}.json"
                        df.to_json(json_filename, orient="records", lines=True)
                        
                        # Displaying the DataFrame
                        print("\nGenerated Robot Movement Data:")
                        print(df)

                        return

    # If the loop completes without stopping, create a DataFrame at the end
    columns = ["Robot Name", "Move", "Timestamp", "Time"]
    df = pd.DataFrame(data_list, columns=columns)

    # Export DataFrame to JSON file
    json_filename = f"robot_movement_data_{iteration_count}.json"
    df.to_json(json_filename, orient="records", lines=True)

    # Displaying the DataFrame
    print("\nGenerated Robot Movement Data:")
    print(df)

if __name__ == "__main__":
    main()
# Out:
# 2023-12-13 15:01:25 - RobotA - Move: grab, Time: 1.36 seconds
# 2023-12-13 15:01:26 - RobotA - Move: implement, Time: 0.86 seconds
# 2023-12-13 15:01:27 - RobotA - Move: set, Time: 1.83 seconds
# 2023-12-13 15:01:28 - RobotB - Move: set, Time: 0.62 seconds
# 2023-12-13 15:01:29 - RobotB - Move: grab, Time: 1.49 seconds
# 2023-12-13 15:01:30 - RobotB - Move: implement, Time: 0.48 seconds
# 2023-12-13 15:01:31 - RobotC - Move: grab, Time: 0.97 seconds
# 2023-12-13 15:01:32 - RobotC - Move: grab, Time: 1.68 seconds
# 2023-12-13 15:01:33 - RobotC - Move: implement, Time: 1.14 seconds
# 2023-12-13 15:01:34 - RobotA - Move: implement, Time: 0.12 seconds
# 2023-12-13 15:01:35 - RobotA - Move: implement, Time: 1.48 seconds
# 2023-12-13 15:01:36 - RobotA - Move: implement, Time: 1.75 seconds
# 2023-12-13 15:01:37 - RobotB - Move: implement, Time: 1.77 seconds
# 2023-12-13 15:01:38 - RobotB - Move: implement, Time: 1.90 seconds
# 2023-12-13 15:01:39 - RobotB - Move: implement, Time: 1.11 seconds
# 2023-12-13 15:01:40 - RobotC - Move: grab, Time: 1.03 seconds
# 2023-12-13 15:01:41 - RobotC - Move: grab, Time: 0.90 seconds
# 2023-12-13 15:01:42 - RobotC - Move: grab, Time: 0.16 seconds
# 2023-12-13 15:01:43 - RobotA - Move: implement, Time: 1.70 seconds
# 2023-12-13 15:01:44 - RobotA - Move: set, Time: 1.02 seconds
# 2023-12-13 15:01:45 - RobotA - Move: implement, Time: 0.60 seconds
# 2023-12-13 15:01:46 - RobotB - Move: implement, Time: 1.59 seconds
# 2023-12-13 15:01:47 - RobotB - Move: set, Time: 0.94 seconds
# 2023-12-13 15:01:48 - RobotB - Move: grab, Time: 1.99 seconds
# 2023-12-13 15:01:49 - RobotC - Move: implement, Time: 0.98 seconds
# 2023-12-13 15:01:50 - RobotC - Move: implement, Time: 0.94 seconds
# 2023-12-13 15:01:51 - RobotC - Move: set, Time: 0.64 seconds
# 2023-12-13 15:01:52 - RobotA - Move: grab, Time: 1.77 seconds
# 2023-12-13 15:01:53 - RobotA - Move: implement, Time: 1.02 seconds
# 2023-12-13 15:01:54 - RobotA - Move: set, Time: 0.61 seconds
# 2023-12-13 15:01:55 - RobotB - Move: grab, Time: 0.94 seconds
# 2023-12-13 15:01:56 - RobotB - Move: grab, Time: 1.02 seconds
# 2023-12-13 15:01:57 - RobotB - Move: set, Time: 1.10 seconds
# 2023-12-13 15:01:58 - RobotC - Move: grab, Time: 1.30 seconds
# 2023-12-13 15:01:59 - RobotC - Move: implement, Time: 0.98 seconds
# 2023-12-13 15:02:00 - RobotC - Move: set, Time: 1.72 seconds
# 2023-12-13 15:02:01 - RobotA - Move: grab, Time: 0.86 seconds
# 2023-12-13 15:02:02 - RobotA - Move: implement, Time: 1.90 seconds
# 2023-12-13 15:02:03 - RobotA - Move: set, Time: 0.93 seconds
# 2023-12-13 15:02:04 - RobotB - Move: implement, Time: 0.16 seconds
# 2023-12-13 15:02:05 - RobotB - Move: set, Time: 0.19 seconds
# 2023-12-13 15:02:06 - RobotB - Move: set, Time: 0.76 seconds
# 2023-12-13 15:02:07 - RobotC - Move: grab, Time: 0.47 seconds
# 2023-12-13 15:02:08 - RobotC - Move: grab, Time: 0.25 seconds
# 2023-12-13 15:02:09 - RobotC - Move: set, Time: 0.45 seconds
# 2023-12-13 15:02:10 - RobotA - Move: set, Time: 0.58 seconds
# 2023-12-13 15:02:11 - RobotA - Move: set, Time: 1.29 seconds
# 2023-12-13 15:02:12 - RobotA - Move: set, Time: 1.84 seconds
# 2023-12-13 15:02:13 - RobotB - Move: set, Time: 0.90 seconds
# 2023-12-13 15:02:14 - RobotB - Move: grab, Time: 1.02 seconds
# 2023-12-13 15:02:15 - RobotB - Move: implement, Time: 1.31 seconds
# 2023-12-13 15:02:16 - RobotC - Move: grab, Time: 0.61 seconds
# 2023-12-13 15:02:17 - RobotC - Move: implement, Time: 1.98 seconds
# 2023-12-13 15:02:18 - RobotC - Move: grab, Time: 0.62 seconds
# 2023-12-13 15:02:19 - RobotA - Move: set, Time: 0.63 seconds
# 2023-12-13 15:02:20 - RobotA - Move: grab, Time: 0.61 seconds
# 2023-12-13 15:02:21 - RobotA - Move: implement, Time: 1.55 seconds
# 2023-12-13 15:02:22 - RobotB - Move: set, Time: 1.12 seconds
# 2023-12-13 15:02:23 - RobotB - Move: implement, Time: 1.55 seconds
# 2023-12-13 15:02:24 - RobotB - Move: implement, Time: 0.76 seconds
# 2023-12-13 15:02:25 - RobotC - Move: grab, Time: 0.35 seconds
# 2023-12-13 15:02:26 - RobotC - Move: implement, Time: 0.87 seconds
# 2023-12-13 15:02:27 - RobotC - Move: set, Time: 1.78 seconds
# 2023-12-13 15:02:28 - RobotA - Move: set, Time: 1.39 seconds
# 2023-12-13 15:02:29 - RobotA - Move: set, Time: 1.91 seconds
# 2023-12-13 15:02:30 - RobotA - Move: set, Time: 1.56 seconds
# 2023-12-13 15:02:31 - RobotB - Move: set, Time: 0.52 seconds
# 2023-12-13 15:02:32 - RobotB - Move: implement, Time: 1.82 seconds
# 2023-12-13 15:02:33 - RobotB - Move: implement, Time: 0.69 seconds
# 2023-12-13 15:02:34 - RobotC - Move: implement, Time: 0.15 seconds
# 2023-12-13 15:02:35 - RobotC - Move: grab, Time: 0.80 seconds
# 2023-12-13 15:02:36 - RobotC - Move: set, Time: 1.95 seconds
# 2023-12-13 15:02:37 - RobotA - Move: grab, Time: 1.34 seconds
# 2023-12-13 15:02:38 - RobotA - Move: grab, Time: 1.20 seconds
# 2023-12-13 15:02:39 - RobotA - Move: set, Time: 1.47 seconds
# 2023-12-13 15:02:40 - RobotB - Move: implement, Time: 0.94 seconds
# 2023-12-13 15:02:41 - RobotB - Move: set, Time: 1.54 seconds
# 2023-12-13 15:02:42 - RobotB - Move: grab, Time: 1.67 seconds
# 2023-12-13 15:02:43 - RobotC - Move: implement, Time: 1.69 seconds
# 2023-12-13 15:02:44 - RobotC - Move: implement, Time: 0.32 seconds
# 2023-12-13 15:02:45 - RobotC - Move: set, Time: 1.73 seconds
# 2023-12-13 15:02:46 - RobotA - Move: implement, Time: 0.38 seconds
# 2023-12-13 15:02:47 - RobotA - Move: grab, Time: 0.61 seconds
# 2023-12-13 15:02:48 - RobotA - Move: set, Time: 1.32 seconds
# 2023-12-13 15:02:49 - RobotB - Move: grab, Time: 0.38 seconds
# 2023-12-13 15:02:50 - RobotB - Move: implement, Time: 1.92 seconds
# 2023-12-13 15:02:51 - RobotB - Move: grab, Time: 0.99 seconds
# 2023-12-13 15:02:52 - RobotC - Move: grab, Time: 1.98 seconds
# 2023-12-13 15:02:53 - RobotC - Move: implement, Time: 1.13 seconds
# 2023-12-13 15:02:54 - RobotC - Move: grab, Time: 1.30 seconds
# 2023-12-13 15:02:55 - RobotA - Move: grab, Time: 1.87 seconds
# 2023-12-13 15:02:56 - RobotA - Move: set, Time: 0.29 seconds
# 2023-12-13 15:02:57 - RobotA - Move: set, Time: 1.88 seconds
# 2023-12-13 15:02:58 - RobotB - Move: grab, Time: 0.75 seconds
# 2023-12-13 15:02:59 - RobotB - Move: grab, Time: 1.64 seconds
# 2023-12-13 15:03:00 - RobotB - Move: grab, Time: 0.67 seconds
# 2023-12-13 15:03:01 - RobotC - Move: grab, Time: 0.53 seconds
# 2023-12-13 15:03:02 - RobotC - Move: grab, Time: 1.21 seconds
# 2023-12-13 15:03:03 - RobotC - Move: set, Time: 1.96 seconds
# 2023-12-13 15:03:04 - RobotA - Move: implement, Time: 1.85 seconds
# Do you want to stop? (yes/no):  yes
# Generated Robot Movement Data:
#    Robot Name       Move            Timestamp      Time
# 0      RobotA       grab  2023-12-13 15:01:25  1.360531
# 1      RobotA  implement  2023-12-13 15:01:26  0.857767
# 2      RobotA        set  2023-12-13 15:01:27  1.825464
# 3      RobotB        set  2023-12-13 15:01:28  0.616464
# 4      RobotB       grab  2023-12-13 15:01:29  1.485137
# ..        ...        ...                  ...       ...
# 95     RobotB       grab  2023-12-13 15:03:00  0.671478
# 96     RobotC       grab  2023-12-13 15:03:01  0.528984
# 97     RobotC       grab  2023-12-13 15:03:02  1.208323
# 98     RobotC        set  2023-12-13 15:03:03  1.956404
# 99     RobotA  implement  2023-12-13 15:03:04  1.845277
#
# [100 rows x 4 columns]
